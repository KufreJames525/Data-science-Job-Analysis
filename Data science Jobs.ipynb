# %% [markdown]
# ### Step 1: Import Necessary Libraries and Loading the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style = "whitegrid")

# %%
data = pd.read_csv(r"C:\Users\Administrator\Desktop\Excel Resources\New Work\DataScience_salaries_2024.csv")

# %%
data
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %% [markdown]
# ### Data Overview

# %%
data.head(2)
# Out:
#    work_year experience_level employment_type        job_title    salary  \
# 0       2021               MI              FT   Data Scientist  30400000
# 1       2021               MI              FT  BI Data Analyst  11000000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             CLP          40038                 CL           100
# 1             HUF          36259                 HU            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  int64
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary              14838 non-null  int64
#  5   salary_currency     14838 non-null  object
#  6   salary_in_usd       14838 non-null  int64
#  7   employee_residence  14838 non-null  object
#  8   remote_ratio        14838 non-null  int64
#  9   company_location    14838 non-null  object
#  10  company_size        14838 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.2+ MB

# %%
data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Checking the different unique values by column
data.nunique()
# Out:
# work_year                5
# experience_level         4
# employment_type          4
# job_title              153
# salary                2363
# salary_currency         23
# salary_in_usd         2730
# employee_residence      88
# remote_ratio             3
# company_location        77
# company_size             3
# dtype: int64

# %%
data['experience_level'].value_counts()
# Out:
# experience_level
# SE    9696
# MI    3553
# EN    1148
# EX     441
# Name: count, dtype: int64

# %%
data['remote_ratio'].value_counts()
# Out:
# remote_ratio
# 0      9853
# 100    4737
# 50      248
# Name: count, dtype: int64

# %%
data['employment_type'].value_counts()
# Out:
# employment_type
# FT    14772
# PT       27
# CT       26
# FL       13
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (14838, 11)

# %%
data.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ### Descriptive Statistics

# %%
data.head(2)
# Out:
#    work_year experience_level employment_type        job_title    salary  \
# 0       2021               MI              FT   Data Scientist  30400000
# 1       2021               MI              FT  BI Data Analyst  11000000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             CLP          40038                 CL           100
# 1             HUF          36259                 HU            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L

# %%
# Descriptive Statistics on numeric columns
data.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  14838.000000  1.483800e+04   14838.000000  14838.000000
# mean    2023.138900  1.650227e+05  149874.718763     32.760480
# std        0.700799  3.562354e+05   69009.181349     46.488278
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.021000e+05  102000.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.875000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %% [markdown]
# ### Visualizing Salary Trends Over Time

# %% [markdown]
# #### 1. Average Salary by Year

# %%
data.head(2)
# Out:
#    work_year experience_level employment_type        job_title    salary  \
# 0       2021               MI              FT   Data Scientist  30400000
# 1       2021               MI              FT  BI Data Analyst  11000000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             CLP          40038                 CL           100
# 1             HUF          36259                 HU            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L

# %%
avg_salary_year = data.groupby('work_year')['salary_in_usd'].mean().reset_index()
avg_salary_year
# Out:
#    work_year  salary_in_usd
# 0       2020  102250.866667
# 1       2021   99922.073394
# 2       2022  134404.072034
# 3       2023  153732.664632
# 4       2024  151510.094422

# %%
plt.figure(figsize=(12,6), facecolor = "gray")

sns.lineplot(x = 'work_year', y = 'salary_in_usd', data = avg_salary_year )
plt.title("Average Salary (USD) in Data Science Jobs by Year")
plt.xlabel("Year")
plt.ylabel("Average Salary in USD")
plt.show()

# %% [markdown]
# #### Salary Distribution by Experience Level

# %%
avg_salary_experience = data.groupby('experience_level')['salary_in_usd'].mean().reset_index()
avg_salary_experience
# Out:
#   experience_level  salary_in_usd
# 0               EN   91656.841463
# 1               EX  194730.210884
# 2               MI  125386.553054
# 3               SE  163700.967100

# %%
plt.figure(figsize = (12,6))
sns.barplot(y='experience_level', x='salary_in_usd', data=avg_salary_experience, palette="viridis")
plt.title("Salary Distribution by Experience Level")
plt.xlabel("Experience Level")
plt.ylabel("Salary in USD")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='experience_level', y='salary_in_usd', data=data, palette="viridis")
plt.title("Salary Distribution by Experience Level")
plt.xlabel("Experience Level")
plt.ylabel("Salary in USD")
plt.show()

# %% [markdown]
# #### Salary Based on Employment Type

# %%
data.head(2)
# Out:
#    work_year experience_level employment_type        job_title    salary  \
# 0       2021               MI              FT   Data Scientist  30400000
# 1       2021               MI              FT  BI Data Analyst  11000000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             CLP          40038                 CL           100
# 1             HUF          36259                 HU            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x ='employment_type', y ='salary_in_usd', data = data , palette = 'Set2')
plt.title("Salary Distribution by Employment Type")
plt.xlabel("Employment Type")
plt.ylabel("Salary in USD")
plt.show()

# %% [markdown]
# #### Salary Distribution by Company Size

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='company_size', y='salary_in_usd', data=data, palette="coolwarm")
plt.title("Salary Distribution by Company Size")
plt.xlabel("Company Size")
plt.ylabel("Salary in USD")
plt.show()

# %% [markdown]
# #### Salary Distribution by Remote Level

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='remote_ratio', y='salary_in_usd', data=data, palette="Blues")
plt.title("Salary Distribution by Remote Work Ratio")
plt.xlabel("Remote Ratio")
plt.ylabel("Salary in USD")
plt.show()

# %% [markdown]
# ## Geographic Analysis

# %% [markdown]
# ### Average Salary By Employee Residence

# %%
avg_salary_by_residence = data.groupby('employee_residence')['salary_in_usd'].mean().sort_values(ascending=False).head(10).reset_index()
avg_salary_by_residence
# Out:
#   employee_residence  salary_in_usd
# 0                 IL  417937.000000
# 1                 QA  300000.000000
# 2                 MY  200000.000000
# 3                 PR  166000.000000
# 4                 US  157701.911032
# 5                 NZ  147681.666667
# 6                 CA  145654.802564
# 7                 SA  139999.333333
# 8                 CH  137187.500000
# 9                 EG  135807.142857

# %%
# Calculate average salary by employee residence
# avg_salary_by_residence = data.groupby('employee_residence')['salary_in_usd'].mean().sort_values(ascending=False).head(10).reset_index()

# Plot
plt.figure(figsize=(12, 8))
sns.barplot(x= 'employee_residence', y = 'salary_in_usd', data = avg_salary_by_residence)
#avg_salary_by_residence.plot(kind='bar', color='coral')
plt.title("Top 10 Employee Residences by Average Salary (USD)")
plt.xlabel("Employee Residence")
plt.ylabel("Average Salary in USD")
plt.show()

# %% [markdown]
# #### Average Salary By Company location

# %%
data.head(2)
# Out:
#    work_year experience_level employment_type        job_title    salary  \
# 0       2021               MI              FT   Data Scientist  30400000
# 1       2021               MI              FT  BI Data Analyst  11000000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             CLP          40038                 CL           100
# 1             HUF          36259                 HU            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L

# %%
# Calculate average salary by company location

avg_salary_by_location = data.groupby('company_location')['salary_in_usd'].mean().sort_values(ascending=False).head(10).reset_index()
avg_salary_by_location
# Out:
#   company_location  salary_in_usd
# 0               QA  300000.000000
# 1               IL  217332.000000
# 2               PR  167500.000000
# 3               US  157410.126474
# 4               NZ  147681.666667
# 5               CA  145174.987245
# 6               EG  140869.230769
# 7               SA  139999.333333
# 8               AU  130126.471698
# 9               MX  129240.600000

# %%
# Plot
plt.figure(figsize=(12, 8))
#avg_salary_by_location.plot(kind='bar', color='seagreen')
sns.barplot(x= "company_location", y = 'salary_in_usd', data = avg_salary_by_location, color='gold')
plt.title("Top 10 Company Locations by Average Salary (USD)")
plt.xlabel("Company Location")
plt.ylabel("Average Salary in USD")
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
numeric_data = data.select_dtypes(include = 'number')
numeric_data
# Out:
#        work_year    salary  salary_in_usd  remote_ratio
# 0           2021  30400000          40038           100
# 1           2021  11000000          36259            50
# 2           2020  11000000          35735            50
# 3           2021   8500000          77364            50
# 4           2022   7500000          95386            50
# ...          ...       ...            ...           ...
# 14833       2022     15000          15000           100
# 14834       2020     15000          15000             0
# 14835       2021     15000          15000           100
# 14836       2022     15000          15000             0
# 14837       2020     14000          15966           100
#
# [14838 rows x 4 columns]

# %%
# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Plot heatmap
plt.figure(figsize=(12, 4))
sns.heatmap(correlation_matrix, annot=True ) #cmap="coolwarm" , vmin=-1, vmax=1)
plt.title("Correlation Matrix for Data Science jobs")
plt.show()

# %% [markdown]
# #### Working With Subplot

# %%
plt.figure(figsize = (12, 8))
plt.subplot(2,2,1)
sns.heatmap(correlation_matrix, annot=True ) #cmap="coolwarm" , vmin=-1, vmax=1)
plt.title("Correlation Matrix for Data Science jobs")
plt.subplot(2,2,2)
sns.barplot(x= "company_location", y = 'salary_in_usd', data = avg_salary_by_location, color='gold')
plt.title("Top 10 Company Locations by Average Salary (USD)")
plt.xlabel("Company Location")
plt.ylabel("Average Salary in USD")
plt.subplot(2,2,3)
sns.barplot(x= 'employee_residence', y = 'salary_in_usd', data = avg_salary_by_residence)
#avg_salary_by_residence.plot(kind='bar', color='coral')
plt.title("Top 10 Employee Residences by Average Salary (USD)")
plt.xlabel("Employee Residence")
plt.ylabel("Average Salary in USD")
plt.subplot(2,2,4)
sns.boxplot(x='experience_level', y='salary_in_usd', data=data, palette="viridis")
plt.title("Salary Distribution by Experience Level")
plt.xlabel("Experience Level")
plt.ylabel("Salary in USD")
plt.tight_layout()
plt.show()
